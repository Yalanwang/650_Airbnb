# %%
import pandas as pd

data1 = pd.read_csv("F:/graduate study/semester2/650/final project/useful/1.csv")
data2 = pd.read_csv("F:/graduate study/semester2/650/final project/useful/2.csv")
data3 = pd.read_csv("F:/graduate study/semester2/650/final project/useful/3.csv")

# %%
data1.head()
# Out:
#   host_response_rate host_acceptance_rate  host_total_listings_count  \
# 0               100%                 100%                         23
# 1                75%                 100%                          1
# 2               100%                 100%                          1
# 3               100%                  90%                          3
# 4               100%                  94%                          1
#
#    host_has_profile_pic  host_identity_verified   latitude   longitude  \
# 0                     1                       1  22.287712  114.148821
# 1                     1                       0  22.286159  114.146969
# 2                     1                       1  22.285770  114.129931
# 3                     1                       1  22.285462  114.136979
# 4                     1                       1  22.283885  114.152385
#
#    is_location_exact property_type     room_type  ...    extra_people  \
# ...

# %%
data2.head()
# Out:
#   host_response_rate host_acceptance_rate  host_total_listings_count  \
# 0                98%                 100%                          5
# 1                98%                 100%                          5
# 2               100%                 100%                          2
# 3               100%                 100%                          1
# 4               100%                 100%                          1
#
#    host_has_profile_pic  host_identity_verified   latitude   longitude  \
# 0                     1                       1  22.267982  114.183846
# 1                     1                       1  22.270117  114.184474
# 2                     1                       1  22.267545  114.188875
# 3                     1                       0  22.286032  114.192022
# 4                     1                       1  22.280958  114.181907
#
#    is_location_exact property_type        room_type   ...    extra_people  \
# ...

# %%
data3.head()
# Out:
#   host_response_rate host_acceptance_rate  host_total_listings_count  \
# 0                96%                 100%                          5
# 1               100%                 100%                          3
# 2               100%                 100%                          1
# 3                90%                  44%                         16
# 4                96%                 100%                         22
#
#   host_has_profile_pic host_identity_verified   latitude   longitude  \
# 0                    t                      f  22.296871  114.170842
# 1                    t                      f  22.298200  114.171473
# 2                    t                      t  22.298159  114.171122
# 3                    t                      t  22.313053  114.170893
# 4                    t                      f  22.305838  114.172752
#
#   is_location_exact property_type     room_type  ...    extra_people  \
# ...

# %%
corr_matx1 = data1.corr()
corr_matx1
# Out:
#                            host_total_listings_count  host_has_profile_pic  \
# host_total_listings_count                   1.000000              0.011811
# host_has_profile_pic                        0.011811              1.000000
# host_identity_verified                      0.204447              0.039764
# latitude                                    0.006920             -0.033681
# longitude                                   0.151502             -0.000866
# is_location_exact                           0.060881             -0.020202
# accommodates                                0.191331              0.013682
# bathrooms                                  -0.037310              0.006861
# bedrooms                                    0.034722              0.001916
# beds                                        0.196016              0.016732
# guests_included                             0.184399              0.009527
# ...

# %%
corr_matx2 = data2.corr()
corr_matx2
# Out:
#                            host_total_listings_count  host_has_profile_pic  \
# host_total_listings_count                   1.000000              0.017087
# host_has_profile_pic                        0.017087              1.000000
# host_identity_verified                     -0.006399              0.024561
# latitude                                    0.109616              0.068385
# longitude                                   0.075620              0.039360
# is_location_exact                          -0.025358              0.000854
# accommodates                               -0.021742              0.014649
# bathrooms                                   0.022108              0.022812
# bedrooms                                   -0.027129             -0.001406
# beds                                        0.007206              0.002211
# guests_included                            -0.054897              0.027489
# ...

# %%
corr_matx3 = data3.corr()
corr_matx3
# Out:
#                            host_total_listings_count  latitude  longitude  \
# host_total_listings_count                   1.000000  0.007847   0.005982
# latitude                                    0.007847  1.000000  -0.508889
# longitude                                   0.005982 -0.508889   1.000000
# accommodates                               -0.077555  0.046852  -0.039656
# bathrooms                                  -0.005971 -0.131333   0.034045
# bedrooms                                   -0.050425  0.081546  -0.050102
# beds                                       -0.032903 -0.035957   0.016819
# guests_included                            -0.079418  0.126677  -0.077839
# minimum_nights                             -0.021443 -0.007176   0.012332
# maximum_nights                             -0.009388  0.023855  -0.002685
# availability_30                             0.129644 -0.061356   0.102632
# availability_60                             0.142108 -0.056440   0.087490
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.heatmap(corr_matx1)
plt.show()

# %%
sns.heatmap(corr_matx2)
plt.show()

# %%
sns.heatmap(corr_matx3)
plt.show()
